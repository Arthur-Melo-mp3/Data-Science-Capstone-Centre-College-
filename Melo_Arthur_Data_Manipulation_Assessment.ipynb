# %% [markdown]
# # Data Manipulation Assessment
# ## DSC 500
# *By Arthur Melo*

# %% [markdown]
# ### Requirements
#
# Write a program that will:
#
# Write a program that:
#
# - (1) Prints out each color in the file in alphabetical order and the number of times it appears in the file.  The first item on each line will contain the word Color if the line has colors in it.
# - (2) Prints out each person in alphabetical order and their associated attributes.
# - (3) Asks the user for a name and an attribute name and prints out the appropriate value.
#
# I chose to do a more manual approach by utilizing conditionals, dictionaries, and loops to manipulate and extract relevant rows and columns. That being said, methods related to sorting, iterrows(), and iloc[] were particularly useful to locate specific rows and do faster data manipulation. This could also have been done in SQL with Common Table Expressions, but using Jupyter Notebooks is just a very fast environment to get it done and document results step by step.

# %% [markdown]
# ## Part 1
#
# - (1) Prints out each color in the file in alphabetical order and the number of times it appears in the file.  The first item on each line will contain the word Color if the line has colors in it.

# %%
import pandas as pd # for data manipulation tasks

# Load the CSV file into a DataFrame
data = pd.read_csv('people_info.csv')

# Display the first few rows of the DataFrame
data.head()
# Out:
#               Name  Chloe    Sofia     Mia  Audrey  Joshua   Nora  Skylar  \
# 0       Hair Color  Black   Blonde  Blonde  Blonde  Blonde  Black   Brown
# 1        Eye Color  Hazel     Blue  Violet    Gray   Green  Brown   Green
# 2   Favorite Color  White   Silver   Black   White    Cyan    Red  Indigo
# 3  Favorite Animal  Horse  Peacock   Panda     Dog   Tiger    Cat   Sloth
# 4  Favorite Number      6        7      42      Pi       6     64      18
#
#    Benjamin     Evelyn  ...      Grace     Hazel  Easton    Aria Christian  \
# 0    Blonde     Auburn  ...     Blonde    Blonde     Red  Blonde    Blonde
# 1     Amber      Brown  ...      Hazel      Blue  Violet   Green      Blue
# 2       Red      Green  ...  Turquoise  Lavender    Teal    Gold     Black
# 3  Elephant  Jellyfish  ...    Cheetah     Tiger    Lion     Cat   Gorilla
# 4         7          3  ...         21         4      21       3        18
#
#   Jonathan    Joseph  Dylan  Carter    Stella
# 0     Gray     Black  Black  Blonde     Brown
# 1    Brown     Amber  Green   Green    Violet
# 2   Indigo    Yellow    Red   Black  Lavender
# 3  Raccoon  Elephant  Panda   Sloth     Panda
# 4        7     64000     11       5  Infinity
#
# [5 rows x 101 columns]

# %%
# Initialize a dictionary to store color counts
color_counts = {}

# Iterate over the rows of the DataFrame
for index, row in data.iterrows():
    # Check if the first column contains the word 'Color'
    if "Color" in row.iloc[0]:
        # Iterate over all columns except the first one
        for value in row.iloc[1:]:
            # Skip missing or NaN values
            if pd.notna(value):
                color = value.strip()  # Remove any leading/trailing whitespace
                # Update the count of the color in the dictionary
                if color in color_counts:
                    color_counts[color] += 1
                else:
                    color_counts[color] = 1

# Sort the dictionary by color name (keys) alphabetically
sorted_colors = dict(sorted(color_counts.items()))

# Print the sorted colors and their counts
for color, count in sorted_colors.items():
    print(f"{color}: {count}")
# Out:
# Amber: 15
# Auburn: 4
# Black: 23
# Blonde: 45
# Blue: 23
# Brown: 45
# Coral: 1
# Crimson: 1
# Cyan: 5
# Fuchsia: 1
# Gold: 1
# Gray: 23
# Green: 19
# Hazel: 16
# Indigo: 5
# Lavender: 2
# Magenta: 2
# Maroon: 2
# Orange: 3
# Pink: 2
# Purple: 5
# Raven: 2
# Red: 15
# Silver: 6
# Spider: 1
# Teal: 3
# Turquoise: 2
# Violet: 10
# White: 6
# Yellow: 12

# %% [markdown]
# ## Part 2
# - (2) Prints out each person in alphabetical order and their associated attributes.

# %%
# Initialize a dictionary to store each person's attributes
person_attributes = {}

# Iterate over the columns (each column represents a person)
for column in data.columns[1:]:  # Exclude the first column, as it contains categories
    # Create a dictionary for each person's attributes
    attributes = {}
    for index, row in data.iterrows():
        category = row.iloc[0]  # First column is the category (e.g., "Hair Color", "Eye Color")
        value = row[column]     # Value for the current column/person
        if pd.notna(value):     # Only include non-NaN values
            attributes[category] = value
    # Store the attributes for the person
    person_attributes[column] = attributes

# Sort the people alphabetically by name
sorted_people = sorted(person_attributes.keys())

# Print each person and their attributes
for person in sorted_people:
    print(f"{person}:")
    for category, value in person_attributes[person].items():
        print(f"  {category}: {value}")
    print()  # Add a blank line for readability
# Out:
# Aaron:
#   Hair Color: Blonde
#   Eye Color: Green
#   Favorite Color: Green
#   Favorite Animal: Cat
#   Favorite Number: 22
#
# Abigail:
#   Hair Color: Red
#   Eye Color: Blue
#   Favorite Color: Gray
#   Favorite Animal: Elephant
#   Favorite Number: 7
#
# Addison:
#   Hair Color: Blonde
#   Eye Color: Gray
#   Favorite Color: Red
#   Favorite Animal: Tiger
#   Favorite Number: 23
#
# Adrian:
#   Hair Color: Red
#   Eye Color: Amber
#   Favorite Color: Purple
#   Favorite Animal: Fox
#   Favorite Number: 23
#
# Alexander:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Magenta
#   Favorite Animal: Kangaroo
#   Favorite Number: 24
#
# Amelia:
#   Hair Color: Auburn
#   Eye Color: Brown
#   Favorite Color: Yellow
#   Favorite Animal: Dolphin
#   Favorite Number: 7
#
# Andrew:
#   Hair Color: Black
#   Eye Color: Gray
#   Favorite Color: Indigo
#   Favorite Animal: Tiger
#   Favorite Number: 23
#
# Anthony:
#   Hair Color: White
#   Eye Color: Green
#   Favorite Color: Silver
#   Favorite Animal: Koala
#   Favorite Number: 12
#
# Aria:
#   Hair Color: Blonde
#   Eye Color: Green
#   Favorite Color: Gold
#   Favorite Animal: Cat
#   Favorite Number: 3
#
# Audrey:
#   Hair Color: Blonde
#   Eye Color: Gray
#   Favorite Color: White
#   Favorite Animal: Dog
#   Favorite Number: Pi
#
# Aurora:
#   Hair Color: Blonde
#   Eye Color: Blue
#   Favorite Color: Crimson
#   Favorite Animal: Dolphin
#   Favorite Number: 2
#
# Aurora.1:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Blue
#   Favorite Animal: Giraffe
#   Favorite Number: 1 google
#
# Ava:
#   Hair Color: Red
#   Eye Color: Brown
#   Favorite Color: Black
#   Favorite Animal: Hedgehog
#   Favorite Number: 1000000
#
# Avery:
#   Hair Color: Brown
#   Eye Color: Hazel
#   Favorite Color: Orange
#   Favorite Animal: Jellyfish
#   Favorite Number: 6
#
# Bella:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Blue
#   Favorite Animal: Monkey
#   Favorite Number: 100
#
# Benjamin:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Red
#   Favorite Animal: Elephant
#   Favorite Number: 7
#
# Brooklyn:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Yellow
#   Favorite Animal: Owl
#   Favorite Number: 25
#
# Caleb:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Blue
#   Favorite Animal: Lemur
#   Favorite Number: 7
#
# Camila:
#   Hair Color: Black
#   Eye Color: Blue
#   Favorite Color: Silver
#   Favorite Animal: Panda
#   Favorite Number: 100
#
# Carter:
#   Hair Color: Blonde
#   Eye Color: Green
#   Favorite Color: Black
#   Favorite Animal: Sloth
#   Favorite Number: 5
#
# Charles:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Yellow
#   Favorite Animal: Frog
#   Favorite Number: 21
#
# Charlotte:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Gray
#   Favorite Animal: Kangaroo
#   Favorite Number: 7
#
# Chloe:
#   Hair Color: Black
#   Eye Color: Hazel
#   Favorite Color: White
#   Favorite Animal: Horse
#   Favorite Number: 6
#
# Christian:
#   Hair Color: Blonde
#   Eye Color: Blue
#   Favorite Color: Black
#   Favorite Animal: Gorilla
#   Favorite Number: 18
#
# Christopher:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Silver
#   Favorite Animal: Deer
#   Favorite Number: 1
#
# Daniel:
#   Hair Color: Black
#   Eye Color: Gray
#   Favorite Color: Yellow
#   Favorite Animal: Giraffe
#   Favorite Number: 1
#
# David:
#   Hair Color: Blonde
#   Eye Color: Gray
#   Favorite Color: Blue
#   Favorite Animal: Bear
#   Favorite Number: 13
#
# Dylan:
#   Hair Color: Black
#   Eye Color: Green
#   Favorite Color: Red
#   Favorite Animal: Panda
#   Favorite Number: 11
#
# Easton:
#   Hair Color: Red
#   Eye Color: Violet
#   Favorite Color: Teal
#   Favorite Animal: Lion
#   Favorite Number: 21
#
# Elena:
#   Hair Color: Raven
#   Eye Color: Brown
#   Favorite Color: Black
#   Favorite Animal: Fox
#   Favorite Number: 23
#
# Eli:
#   Hair Color: Brown
#   Eye Color: Green
#   Favorite Color: Purple
#   Favorite Animal: Monkey
#   Favorite Number: 1
#
# Elijah:
#   Hair Color: Auburn
#   Eye Color: Green
#   Favorite Color: Black
#   Favorite Animal: Eagle
#   Favorite Number: 100
#
# Ella:
#   Hair Color: Blonde
#   Eye Color: Green
#   Favorite Color: Gray
#   Favorite Animal: Wolf
#   Favorite Number: 1
#
# Ellie:
#   Hair Color: Blonde
#   Eye Color: Hazel
#   Favorite Color: Indigo
#   Favorite Animal: Lion
#   Favorite Number: 3
#
# Emily:
#   Hair Color: Gray
#   Eye Color: Green
#   Favorite Color: Black
#   Favorite Animal: Dolphin
#   Favorite Number: 8
#
# Emma:
#   Hair Color: Blonde
#   Eye Color: Gray
#   Favorite Color: Magenta
#   Favorite Animal: Horse
#   Favorite Number: Pi
#
# Ethan:
#   Hair Color: Blonde
#   Eye Color: Violet
#   Favorite Color: Yellow
#   Favorite Animal: Elephant
#   Favorite Number: 3
#
# Evelyn:
#   Hair Color: Auburn
#   Eye Color: Brown
#   Favorite Color: Green
#   Favorite Animal: Jellyfish
#   Favorite Number: 3
#
# Ezra:
#   Hair Color: Blonde
#   Eye Color: Hazel
#   Favorite Color: Turquoise
#   Favorite Animal: Parrot
#   Favorite Number: Pi
#
# Gabriel:
#   Hair Color: Brown
#   Eye Color: Hazel
#   Favorite Color: Green
#   Favorite Animal: Owl
#   Favorite Number: 25
#
# Genesis:
#   Hair Color: Gray
#   Eye Color: Brown
#   Favorite Color: Yellow
#   Favorite Animal: Dolphin
#   Favorite Number: 1000000
#
# Grace:
#   Hair Color: Blonde
#   Eye Color: Hazel
#   Favorite Color: Turquoise
#   Favorite Animal: Cheetah
#   Favorite Number: 21
#
# Hannah:
#   Hair Color: Blonde
#   Eye Color: Gray
#   Favorite Color: Cyan
#   Favorite Animal: Giraffe
#   Favorite Number: 5
#
# Harper:
#   Hair Color: Brown
#   Eye Color: Hazel
#   Favorite Color: Yellow
#   Favorite Animal: Eagle
#   Favorite Number: 3
#
# Hazel:
#   Hair Color: Blonde
#   Eye Color: Blue
#   Favorite Color: Lavender
#   Favorite Animal: Tiger
#   Favorite Number: 4
#
# Henry:
#   Hair Color: Gray
#   Eye Color: Brown
#   Favorite Color: White
#   Favorite Animal: Wolf
#   Favorite Number: 3
#
# Hudson:
#   Hair Color: Auburn
#   Eye Color: Blue
#   Favorite Color: Coral
#   Favorite Animal: Dog
#   Favorite Number: 42
#
# Hunter:
#   Hair Color: Red
#   Eye Color: Amber
#   Favorite Color: White
#   Favorite Animal: Eagle
#   Favorite Number: 69
#
# Isaac:
#   Hair Color: Black
#   Eye Color: Amber
#   Favorite Color: Cyan
#   Favorite Animal: Panda
#   Favorite Number: 65
#
# Isabella:
#   Hair Color: Brown
#   Eye Color: Gray
#   Favorite Color: Red
#   Favorite Animal: Monkey
#   Favorite Number: e
#
# Jack:
#   Hair Color: Blonde
#   Eye Color: Green
#   Favorite Color: Blue
#   Favorite Animal: Penguin
#   Favorite Number: 42
#
# Jackson:
#   Hair Color: Blonde
#   Eye Color: Violet
#   Favorite Color: Blue
#   Favorite Animal: Dolphin
#   Favorite Number: 23
#
# Jacob:
#   Hair Color: Brown
#   Eye Color: Gray
#   Favorite Color: Blue
#   Favorite Animal: Hedgehog
#   Favorite Number: 25
#
# James:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Black
#   Favorite Animal: Zebra
#   Favorite Number: 6
#
# Jeremiah:
#   Hair Color: Brown
#   Eye Color: Brown
#   Favorite Color: Orange
#   Favorite Animal: Octopus
#   Favorite Number: 32
#
# Jonathan:
#   Hair Color: Gray
#   Eye Color: Brown
#   Favorite Color: Indigo
#   Favorite Animal: Raccoon
#   Favorite Number: 7
#
# Joseph:
#   Hair Color: Black
#   Eye Color: Amber
#   Favorite Color: Yellow
#   Favorite Animal: Elephant
#   Favorite Number: 64000
#
# Joshua:
#   Hair Color: Blonde
#   Eye Color: Green
#   Favorite Color: Cyan
#   Favorite Animal: Tiger
#   Favorite Number: 6
#
# Layla:
#   Hair Color: Black
#   Eye Color: Hazel
#   Favorite Color: Indigo
#   Favorite Animal: Fox
#   Favorite Number: Infinity
#
# Levi:
#   Hair Color: Gray
#   Eye Color: Hazel
#   Favorite Color: Blue
#   Favorite Animal: Koala
#   Favorite Number: 25
#
# Liam:
#   Hair Color: Black
#   Eye Color: Violet
#   Favorite Color: Teal
#   Favorite Animal: Flamingo
#   Favorite Number: 4
#
# Lillian:
#   Hair Color: Blonde
#   Eye Color: Gray
#   Favorite Color: Blue
#   Favorite Animal: Penguin
#   Favorite Number: 7
#
# Lily:
#   Hair Color: Brown
#   Eye Color: Amber
#   Favorite Color: White
#   Favorite Animal: Dog
#   Favorite Number: 7
#
# Logan:
#   Hair Color: Brown
#   Eye Color: Amber
#   Favorite Color: Green
#   Favorite Animal: Starfish
#   Favorite Number: 2
#
# Lucas:
#   Hair Color: Blonde
#   Eye Color: Gray
#   Favorite Color: Maroon
#   Favorite Animal: Horse
#   Favorite Number: 1
#
# Lucy:
#   Hair Color: Brown
#   Eye Color: Blue
#   Favorite Color: Blue
#   Favorite Animal: Elephant
#   Favorite Number: 2
#
# Luke:
#   Hair Color: Black
#   Eye Color: Hazel
#   Favorite Color: Cyan
#   Favorite Animal: Wolf
#   Favorite Number: 3
#
# Madison:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Maroon
#   Favorite Animal: Penguin
#   Favorite Number: 100
#
# Mason:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Red
#   Favorite Animal: Turtle
#   Favorite Number: 12
#
# Matthew:
#   Hair Color: Gray
#   Eye Color: Brown
#   Favorite Color: Yellow
#   Favorite Animal: Panda
#   Favorite Number: 7
#
# Maya:
#   Hair Color: Blonde
#   Eye Color: Amber
#   Favorite Color: Green
#   Favorite Animal: Koala
#   Favorite Number: 21
#
# Mia:
#   Hair Color: Blonde
#   Eye Color: Violet
#   Favorite Color: Black
#   Favorite Animal: Panda
#   Favorite Number: 42
#
# Michael:
#   Hair Color: Brown
#   Eye Color: Hazel
#   Favorite Color: Yellow
#   Favorite Animal: Gorilla
#   Favorite Number: 1000000
#
# Naomi:
#   Hair Color: Brown
#   Eye Color: Blue
#   Favorite Color: Blue
#   Favorite Animal: Panda
#   Favorite Number: 25
#
# Nathan:
#   Hair Color: Brown
#   Eye Color: Brown
#   Favorite Color: Red
#   Favorite Animal: Koala
#   Favorite Number: 2
#
# Noah:
#   Hair Color: Brown
#   Eye Color: Brown
#   Favorite Color: Orange
#   Favorite Animal: Dolphin
#   Favorite Number: 7
#
# Nolan:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Teal
#   Favorite Animal: Cat
#   Favorite Number: 42
#
# Nora:
#   Hair Color: Black
#   Eye Color: Brown
#   Favorite Color: Red
#   Favorite Animal: Cat
#   Favorite Number: 64
#
# Nova:
#   Hair Color: Gray
#   Eye Color: Brown
#   Favorite Color: Yellow
#   Favorite Animal: Dog
#   Favorite Number: 1
#
# Oliver:
#   Hair Color: Brown
#   Eye Color: Hazel
#   Favorite Color: Pink
#   Favorite Animal: Elephant
#   Favorite Number: 7
#
# Olivia:
#   Hair Color: Blonde
#   Eye Color: Green
#   Favorite Color: Green
#   Favorite Animal: Rabbit
#   Favorite Number: 2
#
# Owen:
#   Hair Color: Brown
#   Eye Color: Brown
#   Favorite Color: Blue
#   Favorite Animal: Parrot
#   Favorite Number: 15
#
# Paisley:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Purple
#   Favorite Animal: Lion
#   Favorite Number: i
#
# Penelope:
#   Hair Color: Blonde
#   Eye Color: Violet
#   Favorite Color: Gray
#   Favorite Animal: Penguin
#   Favorite Number: 7
#
# Riley:
#   Hair Color: Black
#   Eye Color: Hazel
#   Favorite Color: Red
#   Favorite Animal: Dog
#   Favorite Number: 7
#
# Ryan:
#   Hair Color: Blonde
#   Eye Color: Hazel
#   Favorite Color: Blue
#   Favorite Animal: Turtle
#   Favorite Number: 23
#
# Samuel:
#   Hair Color: Black
#   Eye Color: Violet
#   Favorite Color: Silver
#   Favorite Animal: Owl
#   Favorite Number: 65
#
# Savannah:
#   Hair Color: Blonde
#   Eye Color: Blue
#   Favorite Color: Purple
#   Favorite Animal: Dog
#   Favorite Number: 2
#
# Scarlett:
#   Hair Color: Red
#   Eye Color: Violet
#   Favorite Color: Black
#   Favorite Animal: Cat
#   Favorite Number: 2
#
# Sebastian:
#   Hair Color: Brown
#   Eye Color: Brown
#   Favorite Color: Fuchsia
#   Favorite Animal: Peacock
#   Favorite Number: 8
#
# Skylar:
#   Hair Color: Brown
#   Eye Color: Green
#   Favorite Color: Indigo
#   Favorite Animal: Sloth
#   Favorite Number: 18
#
# Sofia:
#   Hair Color: Blonde
#   Eye Color: Blue
#   Favorite Color: Silver
#   Favorite Animal: Peacock
#   Favorite Number: 7
#
# Sophia:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Red
#   Favorite Animal: Dog
#   Favorite Number: 99
#
# Stella:
#   Hair Color: Brown
#   Eye Color: Violet
#   Favorite Color: Lavender
#   Favorite Animal: Panda
#   Favorite Number: Infinity
#
# Thomas:
#   Hair Color: Raven
#   Eye Color: Gray
#   Favorite Color: Silver
#   Favorite Animal: Dog
#   Favorite Number: 5
#
# Victoria:
#   Hair Color: Brown
#   Eye Color: Hazel
#   Favorite Color: Cyan
#   Favorite Animal: Parrot
#   Favorite Number: 5
#
# Violet:
#   Hair Color: Black
#   Eye Color: Violet
#   Favorite Color: Spider
#   Favorite Animal: Raccoon
#   Favorite Number: 12
#
# Wyatt:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Yellow
#   Favorite Animal: Penguin
#   Favorite Number: 5
#
# Zoe:
#   Hair Color: Blonde
#   Eye Color: Brown
#   Favorite Color: Purple
#   Favorite Animal: Eagle
#   Favorite Number: 21
#
# Zoey:
#   Hair Color: Brown
#   Eye Color: Hazel
#   Favorite Color: Pink
#   Favorite Animal: Chameleon
#   Favorite Number: 3

# %% [markdown]
# ## Part 3
# - (3) Asks the user for a name and an attribute name and prints out the appropriate value.

# %%
# Ask the user for a name and an attribute
person_name = input("Enter the person's name: ")
attribute_name = input("Enter the attribute name: ")

# Retrieve and print the appropriate value
if person_name in person_attributes:
    attributes = person_attributes[person_name]
    if attribute_name in attributes:
        print(f"{attribute_name} of {person_name}: {attributes[attribute_name]}")
    else:
        print(f"Person '{person_name}' not found. You might have also mispelled the person's name or attribute. Please double check it and try again.")
else:
    print(f"Person '{person_name}' not found. You might have also mispelled the person's name or attribute. Please double check it and try again.")
# Out:
# Enter the person's name: Ava
# Enter the attribute name: Eye Color
# Eye Color of Ava: Brown
